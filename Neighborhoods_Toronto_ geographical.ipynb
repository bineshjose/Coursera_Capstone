# %% [markdown]
# # Applied Data Science Capstone
#
# ### Peer-graded Assignment: Segmenting and Clustering Neighborhoods in Toronto
#
#
# Step  1:  Scrape the Wikipedia page, https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M, in order to obtain the data that is in the table of postal codes and to transform the data into a pandas dataframe

# %%
# !pip install wikipedia
# Out:
# ...
#     100% |################################| 92kB 2.1MB/s ta 0:00:011
# ...
#     100% |################################| 92kB 2.5MB/s eta 0:00:01
# ...
#     100% |################################| 143kB 2.0MB/s ta 0:00:01
# ...
#     100% |################################| 61kB 1.9MB/s eta 0:00:01
# ...
#     100% |################################| 153kB 2.1MB/s eta 0:00:01
# ...
#     100% |################################| 143kB 2.6MB/s eta 0:00:01
# ...
#   Running setup.py bdist_wheel for wikipedia ... done
#   Stored in directory: /home/spark/shared/.cache/pip/wheels/87/2a/18/4e471fd96d12114d16fe4a446d00c3b38fb9efcb744bd31f4a
# Successfully built wikipedia
# ...

# %%
import pandas as pd
import wikipedia as wp
 
#Get the html source
html = wp.page("List of postal codes of Canada: M").html().encode("UTF-8")
df = pd.read_html(html)[0]

df.head()
# Out:
#           0             1                 2
# 0  Postcode       Borough     Neighbourhood
# 1       M1A  Not assigned      Not assigned
# 2       M2A  Not assigned      Not assigned
# 3       M3A    North York         Parkwoods
# 4       M4A    North York  Victoria Village

# %% [markdown]
# Step  2: Adjust Column header ,  Ignore cells with a borough  "Not assigned ".

# %%
df.columns = df.iloc[0]
df = df[1:]
df=df[df.Borough != 'Not assigned']
df.head()
# Out:
# 0 Postcode           Borough     Neighbourhood
# 3      M3A        North York         Parkwoods
# 4      M4A        North York  Victoria Village
# 5      M5A  Downtown Toronto      Harbourfront
# 6      M5A  Downtown Toronto       Regent Park
# 7      M6A        North York  Lawrence Heights

# %% [markdown]
# Step 3: If a cell has a borough but a Not assigned neighborhood, then the neighborhood will be the same as the borough.

# %%
df['Neighbourhood'][df.Neighbourhood == 'Not assigned'] = df['Borough']

df.head()
# Out:
# 0 Postcode           Borough     Neighbourhood
# 3      M3A        North York         Parkwoods
# 4      M4A        North York  Victoria Village
# 5      M5A  Downtown Toronto      Harbourfront
# 6      M5A  Downtown Toronto       Regent Park
# 7      M6A        North York  Lawrence Heights

# %% [markdown]
# Step 4 : If more than one neighborhood  exist in one postal code area , combine them with  comma separated

# %%
df1 = df.groupby([('Postcode') , ('Borough')])['Neighbourhood'].apply(lambda x: ', '.join(x.astype(str))).reset_index()
#print (df1)
df1.head(103)
# Out:
#     Postcode           Borough  \
# 0        M1B       Scarborough
# 1        M1C       Scarborough
# 2        M1E       Scarborough
# 3        M1G       Scarborough
# 4        M1H       Scarborough
# 5        M1J       Scarborough
# 6        M1K       Scarborough
# 7        M1L       Scarborough
# 8        M1M       Scarborough
# 9        M1N       Scarborough
# 10       M1P       Scarborough
# 11       M1R       Scarborough
# 12       M1S       Scarborough
# 13       M1T       Scarborough
# 14       M1V       Scarborough
# 15       M1W       Scarborough
# 16       M1X       Scarborough
# 17       M2H        North York
# 18       M2J        North York
# 19       M2K        North York
# 20       M2L        North York
# 21       M2M        North York
# 22       M2N        North York
# 23       M2P        North York
# 24       M2R        North York
# 25       M3A        North York
# 26       M3B        North York
# 27       M3C        North York
# 28       M3H        North York
# ...

# %% [markdown]
# Rename Column name to match with geo data

# %%
df1.rename(columns={'Postcode':'PostalCode'}, inplace=True)
df1.head()
# Out:
#   PostalCode      Borough                           Neighbourhood
# 0        M1B  Scarborough                          Rouge, Malvern
# 1        M1C  Scarborough  Highland Creek, Rouge Hill, Port Union
# 2        M1E  Scarborough       Guildwood, Morningside, West Hill
# 3        M1G  Scarborough                                  Woburn
# 4        M1H  Scarborough                               Cedarbrae

# %% [markdown]
# ### Access Geospatial Data

# %%
df_geo = pd.read_csv('https://cocl.us/Geospatial_data')
print(df_geo)
# Out:
#     Postal Code   Latitude  Longitude
# 0           M1B  43.806686 -79.194353
# 1           M1C  43.784535 -79.160497
# 2           M1E  43.763573 -79.188711
# 3           M1G  43.770992 -79.216917
# 4           M1H  43.773136 -79.239476
# 5           M1J  43.744734 -79.239476
# 6           M1K  43.727929 -79.262029
# 7           M1L  43.711112 -79.284577
# 8           M1M  43.716316 -79.239476
# 9           M1N  43.692657 -79.264848
# 10          M1P  43.757410 -79.273304
# 11          M1R  43.750072 -79.295849
# 12          M1S  43.794200 -79.262029
# 13          M1T  43.781638 -79.304302
# 14          M1V  43.815252 -79.284577
# 15          M1W  43.799525 -79.318389
# 16          M1X  43.836125 -79.205636
# 17          M2H  43.803762 -79.363452
# 18          M2J  43.778517 -79.346556
# 19          M2K  43.786947 -79.385975
# 20          M2L  43.757490 -79.374714
# 21          M2M  43.789053 -79.408493
# 22          M2N  43.770120 -79.408493
# 23          M2P  43.752758 -79.400049
# ...

# %%
df_geo.rename(columns={'Postal Code':'PostalCode'}, inplace=True)

# %% [markdown]
# ### Combine data frame with Geospatial Data

# %%
df_final= (pd.merge(df1, df_geo, on='PostalCode'))
df_final.head(103)
# Out:
#     PostalCode           Borough  \
# 0          M1B       Scarborough
# 1          M1C       Scarborough
# 2          M1E       Scarborough
# 3          M1G       Scarborough
# 4          M1H       Scarborough
# 5          M1J       Scarborough
# 6          M1K       Scarborough
# 7          M1L       Scarborough
# 8          M1M       Scarborough
# 9          M1N       Scarborough
# 10         M1P       Scarborough
# 11         M1R       Scarborough
# 12         M1S       Scarborough
# 13         M1T       Scarborough
# 14         M1V       Scarborough
# 15         M1W       Scarborough
# 16         M1X       Scarborough
# 17         M2H        North York
# 18         M2J        North York
# 19         M2K        North York
# 20         M2L        North York
# 21         M2M        North York
# 22         M2N        North York
# 23         M2P        North York
# 24         M2R        North York
# 25         M3A        North York
# 26         M3B        North York
# ...

# %% [markdown]
# ### Thanks for Review Assignment
